# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Extended_Employee_Performance_and_Productivity_Data.csv')
df.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title  \
# 0            1                IT    Male   55  Specialist
# 1            2           Finance    Male   29   Developer
# 2            3           Finance    Male   55  Specialist
# 3            4  Customer Support  Female   48     Analyst
# 4            5       Engineering  Female   36     Analyst
#
#                     Hire_Date  Years_At_Company Education_Level  \
# 0  2022-01-19 08:03:05.556036                 2     High School
# 1  2024-04-18 08:03:05.556036                 0     High School
# 2  2015-10-26 08:03:05.556036                 8     High School
# 3  2016-10-22 08:03:05.556036                 7        Bachelor
# 4  2021-07-23 08:03:05.556036                 3        Bachelor
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0                  5          6750.0                   33                32
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS(EDA)

# %%
df.dtypes
# Out:
# Employee_ID                      int64
# Department                      object
# Gender                          object
# Age                              int64
# Job_Title                       object
# Hire_Date                       object
# Years_At_Company                 int64
# Education_Level                 object
# Performance_Score                int64
# Monthly_Salary                 float64
# Work_Hours_Per_Week              int64
# Projects_Handled                 int64
# Overtime_Hours                   int64
# Sick_Days                        int64
# Remote_Work_Frequency            int64
# Team_Size                        int64
# Training_Hours                   int64
# Promotions                       int64
# Employee_Satisfaction_Score    float64
# Resigned                          bool
# dtype: object

# %%
df.isnull().sum()
# Out:
# Employee_ID                    0
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Hire_Date                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Salary                 0
# Work_Hours_Per_Week            0
# Projects_Handled               0
# Overtime_Hours                 0
# Sick_Days                      0
# Remote_Work_Frequency          0
# Team_Size                      0
# Training_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# Resigned                       0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# ...

# %%
df.describe()
# Out:
#          Employee_ID            Age  Years_At_Company  Performance_Score  \
# count  100000.000000  100000.000000     100000.000000      100000.000000
# mean    50000.500000      41.029410          4.476070           2.995430
# std     28867.657797      11.244121          2.869336           1.414726
# min         1.000000      22.000000          0.000000           1.000000
# 25%     25000.750000      31.000000          2.000000           2.000000
# 50%     50000.500000      41.000000          4.000000           3.000000
# 75%     75000.250000      51.000000          7.000000           4.000000
# max    100000.000000      60.000000         10.000000           5.000000
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# count   100000.000000        100000.000000     100000.000000   100000.000000
# mean      6403.211000            44.956950         24.431170       14.514930
# std       1372.508717             8.942003         14.469584        8.664026
# ...

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df['Department'].value_counts()
# Out:
# Department
# Marketing           11216
# Finance             11200
# Operations          11181
# IT                  11131
# Sales               11122
# Legal               11118
# Customer Support    11116
# HR                  10960
# Engineering         10956
# Name: count, dtype: int64

# %%
df['Department'].value_counts().plot.pie(autopct='%1.1f%%',title="Department Distribution")
# Out:
# <Axes: title={'center': 'Department Distribution'}, ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      48031
# Female    48001
# Other      3968
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# C:\Users\durka\AppData\Local\Temp\ipykernel_12412\938063210.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel')
# Text(0, 0.5, 'Count')

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Specialist    14507
# Manager       14325
# Technician    14285
# Analyst       14261
# Engineer      14217
# Consultant    14210
# Developer     14195
# Name: count, dtype: int64

# %%
df['Job_Title'].value_counts().plot.pie(autopct='%1.1f%%',title="Job title Distribution")
# Out:
# <Axes: title={'center': 'Job title Distribution'}, ylabel='count'>

# %%
df['Education_Level'].value_counts()
# Out:
# Education_Level
# Bachelor       50041
# High School    30004
# Master         14904
# PhD             5051
# Name: count, dtype: int64

# %%
df['Education_Level'].value_counts().plot.pie(autopct='%1.1f%%',title='Education level distribution')
# Out:
# <Axes: title={'center': 'Education level distribution'}, ylabel='count'>

# %% [markdown]
# DISTRIBUTION OF EACH COLUMNS

# %%
df.skew(numeric_only=True)
# Out:
# Employee_ID                    0.000000
# Age                           -0.006170
# Years_At_Company               0.011211
# Performance_Score              0.004008
# Monthly_Salary                 0.101291
# Work_Hours_Per_Week            0.009621
# Projects_Handled               0.009682
# Overtime_Hours                -0.001167
# Sick_Days                     -0.003320
# Remote_Work_Frequency         -0.001901
# Team_Size                     -0.000592
# Training_Hours                -0.000648
# Promotions                     0.000514
# Employee_Satisfaction_Score    0.001321
# Resigned                       2.664856
# dtype: float64

# %%
num_cols= ['Age', 'Years_At_Company', 'Performance_Score', 'Monthly_Salary',
 'Work_Hours_Per_Week', 'Projects_Handled', 'Overtime_Hours',
 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size',
 'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score']


for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')

# %%
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot for {col}')
    plt.show()

# %% [markdown]
# BIVARIANT ANALYSIS

# %%
ct=pd.crosstab(df['Department'],df['Gender'])
print(ct)
# Out:
# Gender            Female  Male  Other
# Department
# Customer Support    5240  5486    390
# Engineering         5229  5293    434
# Finance             5381  5349    470
# HR                  5260  5221    479
# IT                  5315  5366    450
# Legal               5401  5292    425
# Marketing           5397  5383    436
# Operations          5398  5339    444
# Sales               5380  5302    440

# %%
max_male=ct['Male'].idxmax()
max_female=ct['Female'].idxmax()
print('Department with maximum male:',max_male)
print('Department with maximum female:',max_female)
# Out:
# Department with maximum male: Customer Support
# Department with maximum female: Legal

# %%
df['Hire_Date'] = pd.to_datetime(df['Hire_Date'])
print(df['Hire_Date'])
df['Hire_Date'].dtypes
# Out:
# 0       2022-01-19 08:03:05.556036
# 1       2024-04-18 08:03:05.556036
# 2       2015-10-26 08:03:05.556036
# 3       2016-10-22 08:03:05.556036
# 4       2021-07-23 08:03:05.556036
#                    ...
# 99995   2022-12-07 08:03:05.556036
# 99996   2018-07-24 08:03:05.556036
# 99997   2015-11-24 08:03:05.556036
# 99998   2015-08-03 08:03:05.556036
# 99999   2024-03-04 08:03:05.556036
# Name: Hire_Date, Length: 100000, dtype: datetime64[ns]
# dtype('<M8[ns]')

# %% [markdown]
# CORRELATION HEATMAP

# %%
num_df = df[num_cols]
corr = num_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation Heatmap for Numeric Columns")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap for Numeric Columns')

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Resigned'] = le.fit_transform(df['Resigned'])

# %%
df = pd.get_dummies(df, columns=['Department', 'Job_Title', 'Education_Level'], drop_first=True)
df
# Out:
#        Employee_ID  Gender  Age                  Hire_Date  Years_At_Company  \
# 0                1       1   55 2022-01-19 08:03:05.556036                 2
# 1                2       1   29 2024-04-18 08:03:05.556036                 0
# 2                3       1   55 2015-10-26 08:03:05.556036                 8
# 3                4       0   48 2016-10-22 08:03:05.556036                 7
# 4                5       0   36 2021-07-23 08:03:05.556036                 3
# ...            ...     ...  ...                        ...               ...
# 99995        99996       1   27 2022-12-07 08:03:05.556036                 1
# 99996        99997       0   36 2018-07-24 08:03:05.556036                 6
# 99997        99998       1   53 2015-11-24 08:03:05.556036                 8
# 99998        99999       0   22 2015-08-03 08:03:05.556036                 9
# 99999       100000       0   43 2024-03-04 08:03:05.556036                 0
#
# ...

# %%
df=df.astype(int)
print(df.dtypes)
# Out:
# Employee_ID                    int64
# Gender                         int64
# Age                            int64
# Hire_Date                      int64
# Years_At_Company               int64
# Performance_Score              int64
# Monthly_Salary                 int64
# Work_Hours_Per_Week            int64
# Projects_Handled               int64
# Overtime_Hours                 int64
# Sick_Days                      int64
# Remote_Work_Frequency          int64
# Team_Size                      int64
# Training_Hours                 int64
# Promotions                     int64
# Employee_Satisfaction_Score    int64
# Resigned                       int64
# Department_Engineering         int64
# Department_Finance             int64
# Department_HR                  int64
# Department_IT                  int64
# Department_Legal               int64
# Department_Marketing           int64
# Department_Operations          int64
# Department_Sales               int64
# ...

# %% [markdown]
# COMPARISION OF FEATURES WITH TARGET

# %%
df['Resigned'].value_counts()
# Out:
# Resigned
# 0    89990
# 1    10010
# Name: count, dtype: int64

# %%
resigned_counts = [89990, 10010]
labels = ['Not Resigned', 'Resigned']
plt.figure(figsize=(6,4))
plt.bar(labels, resigned_counts, color=['skyblue', 'salmon'])
plt.xlabel('Resigned')
plt.ylabel('Count')
plt.title('Employee Resignation Count')
# Out:
# Text(0.5, 1.0, 'Employee Resignation Count')

# %%
gender_resigned = df.groupby(['Gender', 'Resigned']).size().unstack()
print(gender_resigned)
# Out:
# Resigned      0     1
# Gender
# 0         43185  4816
# 1         43224  4807
# 2          3581   387

# %%
x=df.drop('Resigned',axis=1)
y=df['Resigned']

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(xtrain)
x_test_scaled=scaler.transform(xtest)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = sm.fit_resample(x_train_scaled, ytrain)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score,recall_score,f1_score,confusion_matrix, classification_report, roc_auc_score, roc_curve

lr = LogisticRegression(class_weight='balanced', random_state=42, max_iter=1000)
lr.fit(x_train_scaled, ytrain)
y_pred_lr = lr.predict(x_test_scaled)
y_prob_lr = lr.predict_proba(x_test_scaled)[:, 1]

print("Logistic Regression")
print("Accuracy:", accuracy_score(ytest, y_pred_lr))
print("Precision:", precision_score(ytest, y_pred_lr))
print("Recall:", recall_score(ytest, y_pred_lr))
print("F1 score:", f1_score(ytest, y_pred_lr))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_lr))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_lr))
# Out:
# Logistic Regression
# Accuracy: 0.5026
# Precision: 0.09714053944433178
# Recall: 0.4785214785214785
# F1 score: 0.16149696561024948
# ROC-AUC Score: 0.4889339463736619
# Confusion Matrix:
#  [[9094 8904]
#  [1044  958]]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=500, random_state=42)
rf.fit(x_train_resampled, y_train_resampled)

y_pred_rf = rf.predict(x_test_scaled)
y_prob_rf = rf.predict_proba(x_test_scaled)[:,1]

print("Random Forest")
print("Accuracy:", accuracy_score(ytest, y_pred_rf))
print("Precision:", precision_score(ytest, y_pred_rf))
print("Recall:", recall_score(ytest, y_pred_rf))
print("F1 score:", f1_score(ytest, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_rf))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_rf))
# Out:
# Random Forest
# Accuracy: 0.8999
# Precision: 0.0
# Recall: 0.0
# F1 score: 0.0
# Confusion Matrix:
#  [[17998     0]
#  [ 2002     0]]
# ROC-AUC Score: 0.4984509878386975
# c:\Users\durka\anaconda3\envs\edafeature_rain\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_resampled, y_train_resampled)

y_pred_knn = knn.predict(x_test_scaled)
y_prob_knn = knn.predict_proba(x_test_scaled)[:,1]

print("KNN")
print("Accuracy:", accuracy_score(ytest, y_pred_knn))
print("Precision:", precision_score(ytest, y_pred_knn))
print("Recall:", recall_score(ytest, y_pred_knn))
print("F1 score:", f1_score(ytest, y_pred_knn))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_knn))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_knn))
# Out:
# KNN
# Accuracy: 0.5781
# Precision: 0.10084346316050607
# Recall: 0.4060939060939061
# F1 score: 0.16156597774244832
# Confusion Matrix:
#  [[10749  7249]
#  [ 1189   813]]
# ROC-AUC Score: 0.5018503970748664

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier(n_estimators=500, random_state=42)
ada.fit(x_train_resampled, y_train_resampled)

y_pred_ada = ada.predict(x_test_scaled)
y_prob_ada = ada.predict_proba(x_test_scaled)[:,1]

print("AdaBoost")
print("Accuracy:", accuracy_score(ytest, y_pred_ada))
print("Precision:", precision_score(ytest, y_pred_ada))
print("Recall:", recall_score(ytest, y_pred_ada))
print("F1 score:", f1_score(ytest, y_pred_ada))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_ada))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_ada))
# Out:
# AdaBoost
# Accuracy: 0.8999
# Precision: 0.0
# Recall: 0.0
# F1 score: 0.0
# Confusion Matrix:
#  [[17998     0]
#  [ 2002     0]]
# ROC-AUC Score: 0.5033641489080982
# c:\Users\durka\anaconda3\envs\edafeature_rain\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(n_estimators=500, random_state=42)
gb.fit(x_train_resampled, y_train_resampled)

y_pred_gb = gb.predict(x_test_scaled)
y_prob_gb = gb.predict_proba(x_test_scaled)[:,1]

print("Gradient Boosting")
print("Accuracy:", accuracy_score(ytest, y_pred_gb))
print("Precision:", precision_score(ytest, y_pred_gb))
print("Recall:", recall_score(ytest, y_pred_gb))
print("F1 score:", f1_score(ytest, y_pred_gb))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_gb))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_gb))
# Out:
# Gradient Boosting
# Accuracy: 0.89975
# Precision: 0.0
# Recall: 0.0
# F1 score: 0.0
# Confusion Matrix:
#  [[17995     3]
#  [ 2002     0]]
# ROC-AUC Score: 0.5025428788346891

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators=500, use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb.fit(x_train_resampled, y_train_resampled)

y_pred_xgb = xgb.predict(x_test_scaled)
y_prob_xgb = xgb.predict_proba(x_test_scaled)[:,1]

print("XGBoost")
print("Accuracy:", accuracy_score(ytest, y_pred_xgb))
print("Precision:", precision_score(ytest, y_pred_xgb))
print("Recall:", recall_score(ytest, y_pred_xgb))
print("F1 score:", f1_score(ytest, y_pred_xgb))
print("Confusion Matrix:\n", confusion_matrix(ytest, y_pred_xgb))
print("ROC-AUC Score:", roc_auc_score(ytest, y_prob_xgb))
# Out:
# c:\Users\durka\anaconda3\envs\edafeature_rain\lib\site-packages\xgboost\training.py:199: UserWarning: [22:43:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost
# Accuracy: 0.89635
# Precision: 0.09195402298850575
# Recall: 0.003996003996003996
# F1 score: 0.007659167065581618
# Confusion Matrix:
#  [[17919    79]
#  [ 1994     8]]
# ROC-AUC Score: 0.4986222939189935
